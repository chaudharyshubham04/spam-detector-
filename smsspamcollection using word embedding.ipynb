# %%
from tensorflow import keras

# %%
from keras.datasets import imdb
# Out:
# Using TensorFlow backend.

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('SMSSpamCollection',sep='\t', names=['label','text'])
df.head()
# Out:
#   label                                               text
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
from keras.preprocessing.text import Tokenizer
token=Tokenizer(num_words=1000)
token.fit_on_texts(df['text'])
word_index=token.word_index

# %%
seq=token.texts_to_sequences(df['text'])

# %%
from keras.preprocessing.sequence import pad_sequences

# %%
padded=pad_sequences(seq)

# %%
print(padded.shape)
# Out:
# (5572, 172)

# %%
#label=pd.get_dummies(df['label'],drop_first=True)
label=label.to_numpy()
lab_train=label[:4500]
lab_test=label[4500:]

# %%
model=keras.models.Sequential([
    keras.layers.Embedding(10000, 64, input_length=172),
    keras.layers.Flatten(),
    keras.layers.Dense(1,activation='sigmoid'),
    
])

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit(padded[:4500],lab_train,epochs=25)
# Out:
# Train on 4500 samples
# Epoch 1/25
# 4500/4500 [==============================] - 2s 439us/sample - loss: 0.0649 - accuracy: 0.9820
# Epoch 2/25
# 4500/4500 [==============================] - 2s 452us/sample - loss: 0.0387 - accuracy: 0.9900
# Epoch 3/25
# 4500/4500 [==============================] - 2s 476us/sample - loss: 0.0269 - accuracy: 0.9922
# Epoch 4/25
# 4500/4500 [==============================] - 2s 454us/sample - loss: 0.0194 - accuracy: 0.9936
# Epoch 5/25
# 4500/4500 [==============================] - 2s 460us/sample - loss: 0.0147 - accuracy: 0.9960
# Epoch 6/25
# 4500/4500 [==============================] - 2s 459us/sample - loss: 0.0111 - accuracy: 0.9978
# Epoch 7/25
# 4500/4500 [==============================] - 2s 456us/sample - loss: 0.0095 - accuracy: 0.9984
# Epoch 8/25
# 4500/4500 [==============================] - 2s 469us/sample - loss: 0.0073 - accuracy: 0.9989
# Epoch 9/25
# ...

# %%
acc=model.evaluate(padded[4500:],lab_test)
# Out:
# 1072/1 [==============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...

# %%
print('loss: ',acc[0])
print('accuracy: ',acc[1])
# Out:
# loss:  0.07277085091221518
# accuracy:  0.9869403
